# %% [markdown]
# # Tutorial 4: Read Write Excel CSV File

# %%
import pandas as pd

# %%
pd.read_csv("weather_data.csv",skiprows=
               2,header=None,names=['Jour','Damperature','vent','event'],nrows=3)
# Out:
#        Jour  Damperature  vent       event
# 0  1/1/2017          NaN     6        Rain
# 1  1/2/2017         35.0     7  don’t know
# 2  1/3/2017         28.0     2        Snow

# %%
df=pd.read_csv("weather_data.csv",na_values={
    "temperature":["not available","don’t know"],
    "windspeed":["not available","don’t know",-1],
    "event":["not available","don’t know"]
})
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017          NaN        6.0   Rain
# 1  1/2/2017         35.0        7.0    NaN
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017         24.0        NaN   Snow
# 4  1/5/2017         32.0        4.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/7/2017          NaN        2.0  Sunny

# %%
#export to csv
df.to_csv("new_weather.csv")

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017          NaN        6.0   Rain
# 1  1/2/2017         35.0        7.0    NaN
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017         24.0        NaN   Snow
# 4  1/5/2017         32.0        4.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/7/2017          NaN        2.0  Sunny

# %%
df['day']=pd.to_datetime(df['day'],format='%m/%d/%Y')

# %%
type(df['day'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01          NaN        6.0   Rain
# 1 2017-01-02         35.0        7.0    NaN
# 2 2017-01-03         28.0        NaN   Snow
# 3 2017-01-04         24.0        NaN   Snow
# 4 2017-01-05         32.0        4.0   Rain
# 5 2017-01-06         31.0        2.0  Sunny
# 6 2017-01-07          NaN        2.0  Sunny

# %%
# new_df=df.fillna({
# "temperature":"unknown",
#     "windspeed":0,
#     "event":"unknown"
    
    
# })

# %%
new_df = df.ffill()
new_df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01          NaN        6.0   Rain
# 1 2017-01-02         35.0        7.0   Rain
# 2 2017-01-03         28.0        7.0   Snow
# 3 2017-01-04         24.0        7.0   Snow
# 4 2017-01-05         32.0        4.0   Rain
# 5 2017-01-06         31.0        2.0  Sunny
# 6 2017-01-07         31.0        2.0  Sunny
